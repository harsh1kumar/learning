# %% [markdown]
# # Santander Customer Transaction Prediction - Random Forest Hyperparam Tuning
#
# In the Kaggle competition, the objective is to identify which customer will make a transaction in the future.
#
# **Link to the competition**: https://www.kaggle.com/c/santander-customer-transaction-prediction/
# **Type of Problem**: Classification
# **Metric for evalution**: AOC (Area Under Curve)
#
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn import metrics

# %%
# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/santander-customer-transaction-prediction/sample_submission.csv
# /kaggle/input/santander-customer-transaction-prediction/train.csv
# /kaggle/input/santander-customer-transaction-prediction/test.csv

# %% [markdown]
# ## Step 1: Import data from CSV

# %%
input_dir = '/kaggle/input/santander-customer-transaction-prediction/'
df_train = pd.read_csv(input_dir + "train.csv")
df_train
# Out:
#              ID_code  target    var_0   var_1    var_2   var_3    var_4  \
# 0            train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607
# 1            train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622
# 2            train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825
# 3            train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846
# 4            train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772
# ...              ...     ...      ...     ...      ...     ...      ...
# 199995  train_199995       0  11.4880 -0.4956   8.2622  3.5142  10.3404
# 199996  train_199996       0   4.9149 -2.4484  16.7052  6.6345   8.3096
# 199997  train_199997       0  11.2232 -5.0518  10.5127  5.6456   9.3410
# 199998  train_199998       0   9.7148 -8.6098  13.6104  5.7930  12.5173
# 199999  train_199999       0  10.8762 -5.7105  12.1183  8.0328  11.5577
#
#           var_5   var_6    var_7  ...  var_190  var_191  var_192  var_193  \
# 0       -9.2834  5.1187  18.6266  ...   4.4354   3.9642   3.1364   1.6910
# 1        7.0433  5.6208  16.5338  ...   7.6421   7.7214   2.5837  10.9516
# 2       -9.0837  6.9427  14.6155  ...   2.9057   9.7905   1.6704   1.6858
# 3       -1.8361  5.8428  14.9250  ...   4.4666   4.7433   0.7178   1.4214
# 4        2.4486  5.9405  19.2514  ...  -1.4905   9.5214  -0.1508   9.1942
# ...         ...     ...      ...  ...      ...      ...      ...      ...
# 199995  11.6081  5.6709  15.1516  ...   6.1415  13.2305   3.9901   0.9388
# 199996 -10.5628  5.8802  21.5940  ...   4.9611   4.6549   0.6998   1.8341
# 199997  -5.4086  4.5555  21.5571  ...   4.0651   5.4414   3.1032   4.8793
# 199998   0.5339  6.0479  17.0152  ...   2.6840   8.6587   2.7337  11.1178
# 199999   0.3488  5.2839  15.2058  ...   8.9842   1.6893   0.1276   0.3766
#
#         var_194  var_195  var_196  var_197  var_198  var_199
# 0       18.5227  -2.3978   7.8784   8.5635  12.7803  -1.0914
# 1       15.4305   2.0339   8.1267   8.7889  18.3560   1.9518
# 2       21.6042   3.1417  -6.5213   8.2675  14.7222   0.3965
# 3       23.0347  -1.2706  -2.9275  10.2922  17.9697  -8.9996
# 4       13.2876  -1.5121   3.9267   9.5031  17.9974  -8.8104
# ...         ...      ...      ...      ...      ...      ...
# 199995  18.0249  -1.7939   2.1661   8.5326  16.6660 -17.8661
# 199996  22.2717   1.7337  -2.1651   6.7419  15.9054   0.3388
# 199997  23.5311  -1.5736   1.2832   8.7155  13.8329   4.1995
# 199998  20.4158  -0.0786   6.7980  10.0342  15.5289 -13.9001
# 199999  15.2101  -2.4907  -2.2342   8.1857  12.1284   0.1385
#
# [200000 rows x 202 columns]

# %%
var_columns =  [c for c in df_train.columns if c not in ['ID_code', 'target'] ]
X = df_train.loc[:, var_columns]
y = df_train.loc[:,'target']
X.shape, y.shape
# Out:
# ((200000, 200), (200000,))

# %% [markdown]
# ## Step2: RandomizedSearchCV
# First, let us get the list of hyperparameters that can be tuned for a RandomForest Model

# %%
RandomForestClassifier().get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# Specify the range of values for some important hyperparameters

# %%
n_estimators_list = list(range(10,220,50))
criterion_list = ['gini', 'entropy']
max_depth_list = list(range(5,41,10))
max_depth_list.append(None)
min_samples_split_list = [x/1000 for x in list(range(5, 41, 10))]
min_samples_leaf_list = [x/1000 for x in list(range(5, 41, 10))]
max_features_list = ['sqrt', 'log2']

params_grid = {
    'n_estimators': n_estimators_list,
    'criterion': criterion_list,
    'max_depth': max_depth_list,
    'min_samples_split': min_samples_split_list,
    'min_samples_leaf': min_samples_leaf_list,
    'max_features': max_features_list
}

num_combinations = 1
for k in params_grid.keys(): num_combinations *= len(params_grid[k])

print('Number of combinations = ', num_combinations)
params_grid
# Out:
# Number of combinations =  1600
# {'n_estimators': [10, 60, 110, 160, 210],
#  'criterion': ['gini', 'entropy'],
#  'max_depth': [5, 15, 25, 35, None],
#  'min_samples_split': [0.005, 0.015, 0.025, 0.035],
#  'min_samples_leaf': [0.005, 0.015, 0.025, 0.035],
#  'max_features': ['sqrt', 'log2']}

# %%
def my_roc_auc_score(model, X, y): return metrics.roc_auc_score(y, model.predict(X))

model_rf = RandomizedSearchCV(estimator=RandomForestClassifier(class_weight='balanced'),
                              param_distributions=params_grid,
                              n_iter=50,
                              cv=3,
                              scoring=my_roc_auc_score,
                              return_train_score=True,
                              verbose=2)

model_rf.fit(X,y)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.6min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 4.0min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 4.0min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 4.0min
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=60; total time=  50.6s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=60; total time=  50.9s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=60; total time=  50.0s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=160; total time= 2.4min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=160; total time= 2.4min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=160; total time= 2.4min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=60; total time=  59.7s
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=60; total time= 1.0min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=60; total time= 1.0min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=210; total time= 4.3min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=210; total time= 4.3min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=210; total time= 4.3min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  19.0s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  19.6s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  19.8s
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=60; total time= 1.8min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=60; total time= 1.7min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=60; total time= 1.8min
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=160; total time= 2.4min
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=160; total time= 2.4min
# [CV] END criterion=gini, max_depth=None, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=160; total time= 2.3min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=110; total time= 1.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=110; total time= 1.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=110; total time= 1.6min
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=10; total time=   9.0s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=10; total time=   8.2s
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=10; total time=   8.8s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=60; total time=  52.1s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=60; total time=  52.6s
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=60; total time=  51.7s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=110; total time= 3.2min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=110; total time= 3.2min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=110; total time= 3.1min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=210; total time= 5.0min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=210; total time= 5.0min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=210; total time= 4.9min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 2.7min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 2.7min
# [CV] END criterion=gini, max_depth=5, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=160; total time= 2.7min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=160; total time= 1.7min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=160; total time= 1.7min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=160; total time= 1.7min
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  12.5s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  12.7s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  12.6s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=160; total time= 6.6min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=160; total time= 6.7min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=160; total time= 6.5min
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 4.5min
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 4.5min
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 4.4min
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=210; total time= 2.2min
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=210; total time= 2.2min
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=210; total time= 2.2min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=110; total time= 2.7min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=110; total time= 2.7min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=110; total time= 2.7min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 1.6min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 1.6min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 1.5min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 3.1min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 3.2min
# [CV] END criterion=gini, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=110; total time= 3.1min
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=60; total time=  54.1s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=60; total time=  51.5s
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=60; total time=  54.2s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=210; total time= 7.3min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=210; total time= 7.4min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=210; total time= 7.4min
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 3.1min
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 3.0min
# [CV] END criterion=entropy, max_depth=None, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.025, n_estimators=110; total time= 3.0min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 4.6min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 4.5min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 4.6min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  16.2s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  15.8s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  14.7s
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 2.6min
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 2.6min
# [CV] END criterion=entropy, max_depth=5, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 2.5min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=210; total time= 2.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=210; total time= 2.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=210; total time= 2.6min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=160; total time= 6.5min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=160; total time= 6.4min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.035, n_estimators=160; total time= 6.5min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=60; total time= 1.6min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=60; total time= 1.7min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=60; total time= 1.6min
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=110; total time= 2.9min
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=110; total time= 2.9min
# [CV] END criterion=entropy, max_depth=None, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.035, n_estimators=110; total time= 2.9min
# [CV] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=60; total time=  32.9s
# [CV] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=60; total time=  32.9s
# [CV] END criterion=gini, max_depth=5, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=60; total time=  32.0s
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.7min
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.7min
# [CV] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=110; total time= 1.7min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=110; total time= 2.7min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=110; total time= 2.7min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.035, n_estimators=110; total time= 2.6min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.0min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.0min
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 2.9min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 6.2min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 6.4min
# [CV] END criterion=gini, max_depth=None, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 6.2min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=210; total time= 4.4min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=210; total time= 4.4min
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.015, n_estimators=210; total time= 4.4min
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  13.5s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  13.3s
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=10; total time=  13.1s
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=160; total time= 2.8min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=160; total time= 2.9min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.015, n_estimators=160; total time= 2.8min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=60; total time= 1.7min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=60; total time= 1.7min
# [CV] END criterion=entropy, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=60; total time= 1.7min
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 3.2min
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 3.2min
# [CV] END criterion=gini, max_depth=25, max_features=log2, min_samples_leaf=0.015, min_samples_split=0.015, n_estimators=210; total time= 3.2min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=60; total time= 1.1min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=60; total time= 1.0min
# [CV] END criterion=entropy, max_depth=15, max_features=log2, min_samples_leaf=0.025, min_samples_split=0.025, n_estimators=60; total time= 1.0min
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=160; total time= 3.2min
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=160; total time= 3.2min
# [CV] END criterion=entropy, max_depth=5, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.035, n_estimators=160; total time= 3.2min
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  11.6s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  12.3s
# [CV] END criterion=gini, max_depth=35, max_features=sqrt, min_samples_leaf=0.035, min_samples_split=0.005, n_estimators=10; total time=  12.8s
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=210; total time= 8.8min
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=210; total time= 8.8min
# [CV] END criterion=entropy, max_depth=35, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.005, n_estimators=210; total time= 8.5min
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  19.9s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  20.2s
# [CV] END criterion=entropy, max_depth=25, max_features=sqrt, min_samples_leaf=0.025, min_samples_split=0.005, n_estimators=10; total time=  19.3s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=10; total time=  18.2s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=10; total time=  17.1s
# [CV] END criterion=gini, max_depth=15, max_features=sqrt, min_samples_leaf=0.015, min_samples_split=0.025, n_estimators=10; total time=  17.2s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=10; total time=  10.7s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=10; total time=  10.4s
# [CV] END criterion=gini, max_depth=15, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.025, n_estimators=10; total time=  10.5s
# RandomizedSearchCV(cv=3,
#                    estimator=RandomForestClassifier(class_weight='balanced'),
#                    n_iter=50,
#                    param_distributions={'criterion': ['gini', 'entropy'],
#                                         'max_depth': [5, 15, 25, 35, None],
#                                         'max_features': ['sqrt', 'log2'],
#                                         'min_samples_leaf': [0.005, 0.015,
#                                                              0.025, 0.035],
#                                         'min_samples_split': [0.005, 0.015,
#                                                               0.025, 0.035],
#                                         'n_estimators': [10, 60, 110, 160,
#                                                          210]},
#                    return_train_score=True,
#                    scoring=<function my_roc_auc_score at 0x7f7127d44320>,
#                    verbose=2)

# %%
model_rf.best_params_
# Out:
# {'n_estimators': 160,
#  'min_samples_split': 0.005,
#  'min_samples_leaf': 0.005,
#  'max_features': 'log2',
#  'max_depth': 35,
#  'criterion': 'entropy'}

# %%
df_cv_results = pd.DataFrame(model_rf.cv_results_)
df_cv_results = df_cv_results[['rank_test_score','mean_test_score','mean_train_score',
                           'param_n_estimators', 'param_min_samples_split','param_min_samples_leaf',
                           'param_max_features', 'param_max_depth','param_criterion']]
df_cv_results.sort_values('rank_test_score', inplace=True)
df_cv_results[:20]
# Out:
#     rank_test_score  mean_test_score  mean_train_score  param_n_estimators  \
# 0                 1         0.759822          0.801006                 160
# 13                2         0.758988          0.797269                 160
# 1                 3         0.753134          0.795035                  60
# 2                 4         0.752450          0.771150                 210
# 14                5         0.752053          0.770428                 210
# 15                6         0.751434          0.770535                 160
# 16                7         0.750773          0.772705                 110
# 3                 8         0.750565          0.774517                 110
# 4                 9         0.750454          0.773879                 160
# 17               10         0.749629          0.768607                 110
# 18               11         0.749500          0.763136                 210
# 19               12         0.749275          0.769450                 110
# 5                13         0.745063          0.760069                 160
# 20               14         0.742103          0.753646                 160
# 21               15         0.741737          0.759060                  60
# 6                16         0.741167          0.755796                  60
# 7                17         0.740232          0.751837                 210
# 8                18         0.739156          0.752569                 110
# 9                19         0.737629          0.750564                  60
# 10               20         0.736508          0.747887                 210
#
#     param_min_samples_split  param_min_samples_leaf param_max_features  \
# 0                     0.005                   0.005               log2
# 13                    0.005                   0.005               log2
# 1                     0.005                   0.005               log2
# 2                     0.035                   0.015               log2
# 14                    0.015                   0.015               log2
# 15                    0.025                   0.015               log2
# 16                    0.015                   0.015               log2
# 3                     0.035                   0.005               log2
# 4                     0.035                   0.005               log2
# 17                    0.015                   0.015               log2
# 18                    0.025                   0.025               log2
# 19                    0.005                   0.015               log2
# 5                     0.015                   0.025               log2
# 20                    0.005                   0.035               log2
# 21                    0.035                   0.015               log2
# 6                     0.025                   0.025               log2
# 7                     0.015                   0.015               log2
# 8                     0.025                   0.035               log2
# 9                     0.015                   0.025               log2
# 10                    0.005                   0.035               log2
#
#     param_max_depth param_criterion
# 0              35.0         entropy
# 13             15.0            gini
# 1              35.0         entropy
# 2              35.0         entropy
# 14             25.0            gini
# 15              NaN            gini
# 16             15.0            gini
# 3               NaN         entropy
# 4              35.0         entropy
# 17             35.0            gini
# 18             15.0            gini
# 19             15.0            gini
# 5              35.0         entropy
# 20             15.0            gini
# 21             25.0            gini
# 6              15.0         entropy
# 7               5.0         entropy
# 8              15.0         entropy
# 9              15.0         entropy
# 10              5.0         entropy

# %%
output_dir = '/kaggle/working/'
df_cv_results.to_csv(output_dir + '/random_search.csv', index=False)

# %% [markdown]
# ## Step3: GridSearchCV

# %%
n_estimators_list = [130,160,190]
criterion_list = ['gini']
max_depth_list = [35,55]
min_samples_split_list = [0.001, 0.005]
min_samples_leaf_list = [0.001, 0.005]
max_features_list = ['log2']

params_grid = {
    'n_estimators': n_estimators_list,
    'criterion': criterion_list,
    'max_depth': max_depth_list,
    'min_samples_split': min_samples_split_list,
    'min_samples_leaf': min_samples_leaf_list,
    'max_features': max_features_list
}

num_combinations = 1
for k in params_grid.keys(): num_combinations *= len(params_grid[k])

print('Number of combinations = ', num_combinations)
params_grid
# Out:
# Number of combinations =  24
# {'n_estimators': [130, 160, 190],
#  'criterion': ['gini'],
#  'max_depth': [35, 55],
#  'min_samples_split': [0.001, 0.005],
#  'min_samples_leaf': [0.001, 0.005],
#  'max_features': ['log2']}

# %%
def my_roc_auc_score(model, X, y): return metrics.roc_auc_score(y, model.predict(X))

model_rf = GridSearchCV(estimator=RandomForestClassifier(class_weight='balanced'),
                        param_grid=params_grid,
                        cv=3,
                        scoring=my_roc_auc_score,
                        return_train_score=True,
                        verbose=4)

model_rf.fit(X,y)
# Out:
# Fitting 3 folds for each of 24 candidates, totalling 72 fits
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.2min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.3min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.5min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.2min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.2min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.3min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 5.1min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 4.9min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 5.0min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.2min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.1min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.1min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 3.8min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 3.8min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 3.9min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.7min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.6min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.6min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.6min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.6min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.7min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.2min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.3min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.3min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.9min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.9min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.9min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.7min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.6min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.7min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.3min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.1min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.2min
# [CV 1/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.7min
# [CV 2/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.8min
# [CV 3/3] END criterion=gini, max_depth=35, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.8min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.3min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.4min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=130; total time= 3.5min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.3min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.1min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=160; total time= 4.1min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 5.0min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 4.9min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.001, n_estimators=190; total time= 4.8min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.2min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.2min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=130; total time= 3.3min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 4.0min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 3.9min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=160; total time= 3.8min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.5min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.6min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.001, min_samples_split=0.005, n_estimators=190; total time= 4.8min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.7min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.6min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=130; total time= 2.6min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.1min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.2min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=160; total time= 3.2min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.8min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.7min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.001, n_estimators=190; total time= 3.6min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.6min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.6min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=130; total time= 2.6min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.2min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.2min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=160; total time= 3.2min
# [CV 1/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.8min
# [CV 2/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.9min
# [CV 3/3] END criterion=gini, max_depth=55, max_features=log2, min_samples_leaf=0.005, min_samples_split=0.005, n_estimators=190; total time= 3.9min
# GridSearchCV(cv=3, estimator=RandomForestClassifier(class_weight='balanced'),
#              param_grid={'criterion': ['gini'], 'max_depth': [35, 55],
#                          'max_features': ['log2'],
#                          'min_samples_leaf': [0.001, 0.005],
#                          'min_samples_split': [0.001, 0.005],
#                          'n_estimators': [130, 160, 190]},
#              return_train_score=True,
#              scoring=<function my_roc_auc_score at 0x7f0c01d1ac20>, verbose=4)

# %%
df_cv_results = pd.DataFrame(model_rf.cv_results_)
df_cv_results = df_cv_results[['rank_test_score','mean_test_score','mean_train_score',
                           'param_n_estimators', 'param_min_samples_split','param_min_samples_leaf',
                           'param_max_features', 'param_max_depth','param_criterion']]
df_cv_results.sort_values('rank_test_score', inplace=True)
df_cv_results
# Out:
#     rank_test_score  mean_test_score  mean_train_score param_n_estimators  \
# 23                1         0.763181          0.803893                190
# 19                2         0.762302          0.801770                160
# 11                3         0.761781          0.804111                190
# 20                4         0.761746          0.804467                190
# 21                5         0.761744          0.802580                130
# 22                6         0.761503          0.803613                160
# 7                 7         0.760930          0.803012                160
# 5                 8         0.760826          0.852796                190
# 8                 9         0.760666          0.802979                190
# 6                10         0.760483          0.802994                130
# 9                11         0.760452          0.801646                130
# 4                12         0.759870          0.853326                160
# 10               13         0.759761          0.802942                160
# 16               14         0.759452          0.850451                160
# 17               15         0.758966          0.851869                190
# 18               16         0.758895          0.800669                130
# 15               17         0.757940          0.849351                130
# 3                18         0.757360          0.849156                130
# 2                19         0.743898          0.891248                190
# 14               20         0.743477          0.891127                190
# 1                21         0.742771          0.890665                160
# 0                22         0.741768          0.888612                130
# 13               23         0.741598          0.890361                160
# 12               24         0.741134          0.888227                130
#
#    param_min_samples_split param_min_samples_leaf param_max_features  \
# 23                   0.005                  0.005               log2
# 19                   0.001                  0.005               log2
# 11                   0.005                  0.005               log2
# 20                   0.001                  0.005               log2
# 21                   0.005                  0.005               log2
# 22                   0.005                  0.005               log2
# 7                    0.001                  0.005               log2
# 5                    0.005                  0.001               log2
# 8                    0.001                  0.005               log2
# 6                    0.001                  0.005               log2
# 9                    0.005                  0.005               log2
# 4                    0.005                  0.001               log2
# 10                   0.005                  0.005               log2
# 16                   0.005                  0.001               log2
# 17                   0.005                  0.001               log2
# 18                   0.001                  0.005               log2
# 15                   0.005                  0.001               log2
# 3                    0.005                  0.001               log2
# 2                    0.001                  0.001               log2
# 14                   0.001                  0.001               log2
# 1                    0.001                  0.001               log2
# 0                    0.001                  0.001               log2
# 13                   0.001                  0.001               log2
# 12                   0.001                  0.001               log2
#
#    param_max_depth param_criterion
# 23              55            gini
# 19              55            gini
# 11              35            gini
# 20              55            gini
# 21              55            gini
# 22              55            gini
# 7               35            gini
# 5               35            gini
# 8               35            gini
# 6               35            gini
# 9               35            gini
# 4               35            gini
# 10              35            gini
# 16              55            gini
# 17              55            gini
# 18              55            gini
# 15              55            gini
# 3               35            gini
# 2               35            gini
# 14              55            gini
# 1               35            gini
# 0               35            gini
# 13              55            gini
# 12              55            gini

# %%
output_dir = '/kaggle/working/'
df_cv_results.to_csv(output_dir + '/grid_search.csv', index=False)

# %%
model_rf.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 55,
#  'max_features': 'log2',
#  'min_samples_leaf': 0.005,
#  'min_samples_split': 0.005,
#  'n_estimators': 190}

# %% [markdown]
# ## Step4: Create the final model and evaluate the performance

# %%
model_rf_fin = RandomForestClassifier(class_weight='balanced',
                                      criterion='gini',
                                      max_depth=55,
                                      max_features='log2',
                                      min_samples_leaf=0.005,
                                      min_samples_split=0.005,
                                      n_estimators=190)
model_rf_fin.fit(X,y)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=55,
#                        max_features='log2', min_samples_leaf=0.005,
#                        min_samples_split=0.005, n_estimators=190)

# %%
print('AUC Score = {:.4f}'.format(metrics.roc_auc_score(y, model_rf_fin.predict(X))))
# Out:
# AUC Score = 0.7877
